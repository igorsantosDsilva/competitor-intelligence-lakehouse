# %%
# %sql
CREATE VOLUME IF NOT EXISTS raw;

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/raw/bairros")
dbutils.fs.mkdirs("/Volumes/workspace/default/raw/concorrentes")
dbutils.fs.mkdirs("/Volumes/workspace/default/raw/eventos_de_fluxo")
dbutils.fs.mkdirs("/Volumes/workspace/default/raw/populacao")

# %%
# %sql
LIST '/Volumes/workspace/default/raw/bairros';

# %%
# %sql
CREATE CATALOG IF NOT EXISTS competitor_intelligence_dev;
USE CATALOG competitor_intelligence_dev;
CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold
